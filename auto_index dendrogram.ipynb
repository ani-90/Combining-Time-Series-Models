# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
apollo=pd.Series(pd.read_csv('/content/apollo tyres.csv')['Close Price'],name='apollo')
ashokleyland=pd.Series(pd.read_csv('/content/ashokleyland.csv')['Close Price'],name='ashokleyland')
bajaj=pd.Series(pd.read_csv('/content/bajaj.csv')['Close Price'],name='bajaj')
balkrishna_motors=pd.Series(pd.read_csv('/content/balkrishna industries.csv')['Close Price'],name='balkrishna_motors')
bosch=pd.Series(pd.read_csv('/content/bosch.csv')['Close Price'],name='bosch')
cummins=pd.Series(pd.read_csv('/content/cummins.csv')['Close Price'],name='cummins')
eichermotors=pd.Series(pd.read_csv('/content/eichermotors.csv')['Close Price'],name='eichermotors')
heromotors=pd.Series(pd.read_csv('/content/heromotors.csv')['Close Price'],name='heromotors')
mahindra=pd.Series(pd.read_csv('/content/mahindra and manindra.csv')['Close Price'],name='mahindra')
maruti=pd.Series(pd.read_csv('/content/maruti suzuki.csv')['Close Price'],name='maruti')
motherson=pd.Series(pd.read_csv('/content/motherson.csv')['Close Price'],name='motherson')
mrf=pd.Series(pd.read_csv('/content/mrf.csv')['Close Price'],name='mrf')
tatamotors=pd.Series(pd.read_csv('/content/tatamotors.csv')['Close Price'],name='tatamotors')
tube_investments=pd.Series(pd.read_csv('/content/tube investments.csv')['Close Price'],name='tube investments')
tvs_motors=pd.Series(pd.read_csv('/content/tvs motors.csv')['Close Price'],name='tvs motors')

# %%
df=pd.concat([apollo,ashokleyland,bajaj,balkrishna_motors,bosch,cummins,eichermotors,heromotors,mahindra,maruti,motherson,mrf,tatamotors,tube_investments,tvs_motors],axis=1)
df.head()
# Out:
#    apollo  ashokleyland    bajaj  balkrishna_motors     bosch  cummins  \
# 0  427.50        183.10  6089.60            2578.80  21591.75  1910.50
# 1  425.90        181.20  6065.05            2583.95  21681.45  1873.15
# 2  422.75        179.00  6002.60            2620.70  21252.30  1874.35
# 3  414.70        178.35  5929.80            2569.35  21026.85  1870.75
# 4  420.90        177.95  5921.85            2552.35  21208.70  1874.65
#
#    eichermotors  heromotors  mahindra    maruti  motherson        mrf  \
# 0       3898.85     3819.05   1647.60  10604.10      92.04  111746.85
# 1       3812.70     3745.75   1618.90  10590.20      92.58  112261.50
# 2       3829.05     3622.25   1565.95  10537.15      89.93  111524.80
# 3       3847.10     3546.90   1552.70  10518.10      87.50  111401.25
# 4       3881.75     3568.75   1545.95  10494.00      88.21  111399.80
#
#    tatamotors  tube investments  tvs motors
# 0      706.25           3368.25     1870.65
# 1      712.15           3450.90     1862.00
# 2      697.60           3421.55     1824.80
# 3      673.65           3467.15     1800.25
# 4      679.85           3420.75     1775.65

# %%
## plotting correlation between the closing stock prices of the above automobile companies
df.corr()
# Out:
#                      apollo  ashokleyland     bajaj  balkrishna_motors  \
# apollo             1.000000      0.806590  0.787393           0.540463
# ashokleyland       0.806590      1.000000  0.766150           0.626250
# bajaj              0.787393      0.766150  1.000000           0.737981
# balkrishna_motors  0.540463      0.626250  0.737981           1.000000
# bosch                      0.316761    0.256354
# cummins                    0.200135    0.191947
# eichermotors               0.270587    0.308540
# heromotors                 0.600743    0.448668
# mahindra                   0.162943    0.120702
# maruti                     0.321755    0.150064
# motherson                  0.536937    0.627336
# mrf                        0.162796    0.082059
# tatamotors                 0.661018    0.438107
# tube investments           0.000000    0.157360
# tvs motors                 0.157360    0.000000

# %%
## classifying relationships based on the values of distance matrix

weak=[]
moderate=[]
strong=[]
cols=list(distance.columns)
for i in range(len(cols)-1):
  c1=cols[i]
  for j in range(i+1,len(cols)):
    c2=cols[j]
    val=distance[c1][c2]

    if 0.75<=val<=1:
      if [c1,c2] and [c2,c1] not in weak:
        weak.append([c1,c2])
    elif 0.36<=val<0.75:
      if [c1,c2] and [c2,c1] not in moderate:
        moderate.append([c1,c2])

    elif 0<=val<=0.36:
      if [c1,c2] and [c2,c1] not in strong:
        strong.append([c1,c2])

# %%
print('auto mobile companies with weak relationship: ',weak)
print('auto mobile companies with moderate relationship: ',moderate)
print('auto mobile companies with Strong relationship: ',strong)
# Out:
# auto mobile companies with weak relationship:  [['ashokleyland', 'motherson'], ['bajaj', 'motherson'], ['balkrishna_motors', 'cummins'], ['balkrishna_motors', 'eichermotors'], ['balkrishna_motors', 'motherson'], ['balkrishna_motors', 'tube investments'], ['bosch', 'motherson'], ['eichermotors', 'tatamotors'], ['heromotors', 'motherson'], ['maruti', 'motherson'], ['motherson', 'tatamotors']]
# auto mobile companies with moderate relationship:  [['apollo', 'bajaj'], ['apollo', 'balkrishna_motors'], ['apollo', 'eichermotors'], ['apollo', 'heromotors'], ['apollo', 'motherson'], ['apollo', 'tatamotors'], ['ashokleyland', 'bajaj'], ['ashokleyland', 'balkrishna_motors'], ['ashokleyland', 'bosch'], ['ashokleyland', 'cummins'], ['ashokleyland', 'eichermotors'], ['ashokleyland', 'tatamotors'], ['bajaj', 'balkrishna_motors'], ['bajaj', 'bosch'], ['bajaj', 'cummins'], ['bajaj', 'eichermotors'], ['bajaj', 'heromotors'], ['bajaj', 'mahindra'], ['bajaj', 'tube investments'], ['balkrishna_motors', 'bosch'], ['balkrishna_motors', 'heromotors'], ['balkrishna_motors', 'mahindra'], ['balkrishna_motors', 'maruti'], ['balkrishna_motors', 'mrf'], ['balkrishna_motors', 'tvs motors'], ['bosch', 'eichermotors'], ['bosch', 'heromotors'], ['bosch', 'mahindra'], ['bosch', 'tatamotors'], ['cummins', 'eichermotors'], ['cummins', 'heromotors'], ['cummins', 'maruti'], ['cummins', 'motherson'], ['cummins', 'tatamotors'], ['eichermotors', 'heromotors'], ['eichermotors', 'maruti'], ['eichermotors', 'motherson'], ['heromotors', 'mahindra'], ['heromotors', 'mrf'], ['heromotors', 'tatamotors'], ['heromotors', 'tube investments'], ['heromotors', 'tvs motors'], ['mahindra', 'motherson'], ['mahindra', 'tatamotors'], ['motherson', 'mrf'], ['motherson', 'tube investments'], ['motherson', 'tvs motors'], ['mrf', 'tatamotors'], ['tatamotors', 'tube investments'], ['tatamotors', 'tvs motors']]
# auto mobile companies with Strong relationship:  [['apollo', 'ashokleyland'], ['apollo', 'bosch'], ['apollo', 'cummins'], ['apollo', 'mahindra'], ['apollo', 'maruti'], ['apollo', 'mrf'], ['apollo', 'tube investments'], ['apollo', 'tvs motors'], ['ashokleyland', 'heromotors'], ['ashokleyland', 'mahindra'], ['ashokleyland', 'maruti'], ['ashokleyland', 'mrf'], ['ashokleyland', 'tube investments'], ['ashokleyland', 'tvs motors'], ['bajaj', 'maruti'], ['bajaj', 'mrf'], ['bajaj', 'tatamotors'], ['bajaj', 'tvs motors'], ['balkrishna_motors', 'tatamotors'], ['bosch', 'cummins'], ['bosch', 'maruti'], ['bosch', 'mrf'], ['bosch', 'tube investments'], ['bosch', 'tvs motors'], ['cummins', 'mahindra'], ['cummins', 'mrf'], ['cummins', 'tube investments'], ['cummins', 'tvs motors'], ['eichermotors', 'mahindra'], ['eichermotors', 'mrf'], ['eichermotors', 'tube investments'], ['eichermotors', 'tvs motors'], ['heromotors', 'maruti'], ['mahindra', 'maruti'], ['mahindra', 'mrf'], ['mahindra', 'tube investments'], ['mahindra', 'tvs motors'], ['maruti', 'mrf'], ['maruti', 'tatamotors'], ['maruti', 'tube investments'], ['maruti', 'tvs motors'], ['mrf', 'tube investments'], ['mrf', 'tvs motors'], ['tube investments', 'tvs motors']]

# %%
## Applying Principal Component Analysis for the distance matrix

from sklearn.decomposition import PCA
pca=PCA(n_components=4)
pca.fit(distance)
# Out:
# PCA(n_components=4)

# %%
pca_data=pd.DataFrame(pca.fit_transform(distance))
pca_data
# Out:
#            0         1         2         3
# 0  -0.479534  0.052581 -0.264305  0.004793
# 1  -0.120700 -0.263744  0.318059 -0.093523
# 2   0.257895 -0.475498 -0.203877 -0.091154
# 3   1.339218 -0.204546 -0.084252  0.061161
# 4  -0.141247 -0.037468 -0.267365  0.321606
# 5  -0.379842  0.213222 -0.379399 -0.037493
# 6  -0.142208  0.575949  0.393760  0.248559
# 7   0.604075 -0.366241  0.379612 -0.014289
# 8  -0.526371  0.042187  0.199472 -0.117488
# 9  -0.195538 -0.400537  0.188810  0.023113
# 10  0.733199  1.461142 -0.052482 -0.151255
# 11 -0.534743 -0.216636 -0.025031 -0.081142
# 12  0.696420 -0.553281 -0.179215 -0.019271
# 13 -0.541198  0.328260  0.004854  0.030081
# 14 -0.569426 -0.155389 -0.028639 -0.083699

# %%
# Explained variance ratio
explained_variance_ratio = pca.explained_variance_ratio_
cumulative_explained_variance = explained_variance_ratio.cumsum()

# Plot the explained variance
plt.plot(range(1, len(cumulative_explained_variance) + 1), cumulative_explained_variance, marker='o')
plt.title('Cumulative Explained Variance')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.show()

# %%
from scipy.cluster.hierarchy import linkage, dendrogram
linkage_matrix = linkage(pca_data, method='complete', metric='euclidean')

plt.figure(figsize=(10, 8))
dendrogram(linkage_matrix, labels=distance.index, orientation='top', distance_sort='descending', show_leaf_counts=True)
plt.title('Hierarchical Clustering Dendrogram (PCA Data)')
plt.xticks(rotation=90)
plt.xlabel('Auto Index Companies')
plt.ylabel('Distance')
plt.show()
